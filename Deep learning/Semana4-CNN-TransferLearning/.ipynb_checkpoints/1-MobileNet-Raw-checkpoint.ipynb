# %% [markdown]
# ### http://image-net.org/

# %%
import warnings
warnings.filterwarnings('ignore')

import os
import sys
import numpy as np
from skimage.io import imread
import matplotlib.pyplot as plt

import keras
from keras.applications.imagenet_utils import decode_predictions
from keras.preprocessing import image

# %%
img = imread('img/panda.png')

plt.figure(figsize=(10, 10))
plt.axis('off')
plt.imshow(img)

# %%
# cargamos 
model = keras.applications.MobileNet(weights = 'imagenet')

# tenemos el tamano de la imagen que espera el modelo. (224)
IMG_SIZE = model.input_shape[1]

img = image.load_img('img/panda.png', target_size=(IMG_SIZE, IMG_SIZE,3), interpolation="nearest")
x = image.img_to_array(img) / 255.
x = np.expand_dims(x, axis=0)

y = model.predict(x)
decode_predictions(y)
# Out:
# [[('n02510455', 'giant_panda', 0.9983188),
#   ('n02108915', 'French_bulldog', 0.0007230382),
#   ('n04254680', 'soccer_ball', 0.0001125484),
#   ('n02093428', 'American_Staffordshire_terrier', 0.00011097535),
#   ('n02108089', 'boxer', 9.229645e-05)]]

# %%
img = imread('img/bird.jpg')

plt.figure(figsize=(10, 10))
plt.axis('off')
plt.imshow(img)

# %%
img = image.load_img('img/bird.jpg', target_size=(IMG_SIZE, IMG_SIZE,3), interpolation="nearest")
x = image.img_to_array(img) / 255.
x = np.expand_dims(x, axis=0)

y = model.predict(x)
decode_predictions(y)
# Out:
# [[('n01530575', 'brambling', 0.5693865),
#   ('n01531178', 'goldfinch', 0.13292645),
#   ('n01828970', 'bee_eater', 0.11642804),
#   ('n01532829', 'house_finch', 0.09796055),
#   ('n01558993', 'robin', 0.027704766)]]
