# %% [markdown]
# ## Practica Semanal Calificada
#
# Ud va a desarrollar un modelo de clasificacion binaria utilizando **regresion logistica** para determinar si un paciente tiene o no un padecimiento cardiaco.
#
# La variable a predecir es la variable "target" la cual tiene valores de 1 y 0. Donde 1 es que el paciente tiene un padecimiento cardiaco.
#
# Los atributos X son los siguientes:
#
# - age
# - sex
# - chest pain type (4 values)
# - resting blood pressure
# - serum cholestoral in mg/dl
# - fasting blood sugar > 120 mg/dl
# - resting electrocardiographic results (values 0,1,2)
# - maximum heart rate achieved
# - exercise induced angina
# - oldpeak = ST depression induced by exercise relative to rest
# - the slope of the peak exercise ST segment
# - number of major vessels (0-3) colored by flourosopy
# - thal: 3 = normal; 6 = fixed defect; 7 = reversable defect
#
# El dataset contiene 303 registros de un hospital de Cleveland. Es recomendable que lea el siguiente [paper](https://www.researchgate.net/publication/309210947_Heart_Disease_prediction_using_Machine_learning_and_Data_Mining_Technique/link/5805eb0f08ae03256b75d9a1/download) para que obtenga un mejor conocimiento sobre el trasfondo del problema.

# %%
import pandas as pd
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt 
from sklearn.preprocessing import normalize
import numpy as np

# %%
data = pd.read_csv("data/heart.csv")
data
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %%
# Despliego la matriz de correlacion para darme una idea de la interaccion de los features
corr = data.corr()

# Desplegar la matriz de correlaciones con pandas
corr.style.background_gradient(cmap='plasma').set_precision(2)
# Out:
# <style  type="text/css" >
# #T_98d31bba_ecb2_11ea_baa3_acde48001122row0_col0,#T_98d31bba_ecb2_11ea_baa3_acde48001122row1_col1,#T_98d31bba_ecb2_11ea_baa3_acde48001122row2_col2,#T_98d31bba_ecb2_11ea_baa3_acde48001122row3_col3,#T_98d31bba_ecb2_11ea_baa3_acde48001122row4_col4,#T_98d31bba_ecb2_11ea_baa3_acde48001122row5_col5,#T_98d31bba_ecb2_11ea_baa3_acde48001122row6_col6,#T_98d31bba_ecb2_11ea_baa3_acde48001122row7_col7,#T_98d31bba_ecb2_11ea_baa3_acde48001122row8_col8,#T_98d31bba_ecb2_11ea_baa3_acde48001122row9_col9,#T_98d31bba_ecb2_11ea_baa3_acde48001122row10_col10,#T_98d31bba_ecb2_11ea_baa3_acde48001122row11_col11,#T_98d31bba_ecb2_11ea_baa3_acde48001122row12_col12,#T_98d31bba_ecb2_11ea_baa3_acde48001122row13_col13{
#             background-color:  #f0f921;
#             color:  #000000;
#         }#T_98d31bba_ecb2_11ea_baa3_acde48001122row0_col1{
#             background-color:  #5302a3;
#             color:  #f1f1f1;
#         }#T_98d31bba_ecb2_11ea_baa3_acde48001122row0_col2,#T_98d31bba_ecb2_11ea_baa3_acde48001122row4_col3,#T_98d31bba_ecb2_11ea_baa3_acde48001122row5_col12{
#             background-color:  #7701a8;
#             color:  #f1f1f1;
#         }#T_98d31bba_ecb2_11ea_baa3_acde48001122row0_col3,#T_98d31bba_ecb2_11ea_baa3_acde48001122row5_col9,#T_98d31bba_ecb2_11ea_baa3_acde48001122row10_col2,#T_98d31bba_ecb2_11ea_baa3_acde48001122row11_col12{
#             background-color:  #a72197;
#             color:  #f1f1f1;
#         }#T_98d31bba_ecb2_11ea_baa3_acde48001122row0_col4{
#             background-color:  #9e199d;
#             color:  #f1f1f1;
#         }#T_98d31bba_ecb2_11ea_baa3_acde48001122row0_col5{
#             background-color:  #6600a7;
#             color:  #f1f1f1;
#         }#T_98d31bba_ecb2_11ea_baa3_acde48001122row0_col6,#T_98d31bba_ecb2_11ea_baa3_acde48001122row2_col8{
#             background-color:  #20068f;
#             color:  #f1f1f1;
#         }#T_98d31bba_ecb2_11ea_baa3_acde48001122row0_col7,#T_98d31bba_ecb2_11ea_baa3_acde48001122row1_col4,#T_98d31bba_ecb2_11ea_baa3_acde48001122row4_col6,#T_98d31bba_ecb2_11ea_baa3_acde48001122row6_col5,#T_98d31bba_ecb2_11ea_baa3_acde48001122row7_col0,#T_98d31bba_ecb2_11ea_baa3_acde48001122row8_col2,#T_98d31bba_ecb2_11ea_baa3_acde48001122row8_col13,#T_98d31bba_ecb2_11ea_baa3_acde48001122row9_col10,#T_98d31bba_ecb2_11ea_baa3_acde48001122row10_col9,#T_98d31bba_ecb2_11ea_baa3_acde48001122row13_col1,#T_98d31bba_ecb2_11ea_baa3_acde48001122row13_col3,#T_98d31bba_ecb2_11ea_baa3_acde48001122row13_col8,#T_98d31bba_ecb2_11ea_baa3_acde48001122row13_col11,#T_98d31bba_ecb2_11ea_baa3_acde48001122row13_col12{
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#         }#T_98d31bba_ecb2_11ea_baa3_acde48001122row0_col8,#T_98d31bba_ecb2_11ea_baa3_acde48001122row5_col0{
#             background-color:  #a82296;
#             color:  #f1f1f1;
#         }#T_98d31bba_ecb2_11ea_baa3_acde48001122row0_col9,#T_98d31bba_ecb2_11ea_baa3_acde48001122row2_col7,#T_98d31bba_ecb2_11ea_baa3_acde48001122row12_col9{
#             background-color:  #cb4679;
#             color:  #f1f1f1;
#         }#T_98d31bba_ecb2_11ea_baa3_acde48001122row0_col10{
#             background-color:  #8104a7;
#             color:  #f1f1f1;
#         }#T_98d31bba_ecb2_11ea_baa3_acde48001122row0_col11{
#             background-color:  #c6417d;
#             color:  #f1f1f1;
#         }#T_98d31bba_ecb2_11ea_baa3_acde48001122row0_col12{
#             background-color:  #920fa3;
#             color:  #f1f1f1;
#         }#T_98d31bba_ecb2_11ea_baa3_acde48001122row0_col13,#T_98d31bba_ecb2_11ea_baa3_acde48001122row7_col9{
#             background-color:  #5502a4;
#             color:  #f1f1f1;
#         }#T_98d31bba_ecb2_11ea_baa3_acde48001122row1_col0,#T_98d31bba_ecb2_11ea_baa3_acde48001122row10_col6{
#             background-color:  #6f00a8;
#             color:  #f1f1f1;
#         }#T_98d31bba_ecb2_11ea_baa3_acde48001122row1_col2,#T_98d31bba_ecb2_11ea_baa3_acde48001122row6_col12,#T_98d31bba_ecb2_11ea_baa3_acde48001122row12_col4{
#             background-color:  #7d03a8;
#             color:  #f1f1f1;
#         }#T_98d31bba_ecb2_11ea_baa3_acde48001122row1_col3{
#             background-color:  #370499;
#             color:  #f1f1f1;
#         }#T_98d31bba_ecb2_11ea_baa3_acde48001122row1_col5,#T_98d31bba_ecb2_11ea_baa3_acde48001122row12_col6{
#             background-color:  #4903a0;
#             color:  #f1f1f1;
#         }#T_98d31bba_ecb2_11ea_baa3_acde48001122row1_col6,#T_98d31bba_ecb2_11ea_baa3_acde48001122row9_col6{
#             background-color:  #38049a;
#             color:  #f1f1f1;
#         }#T_98d31bba_ecb2_11ea_baa3_acde48001122row1_col7,#T_98d31bba_ecb2_11ea_baa3_acde48001122row3_col7,#T_98d31bba_ecb2_11ea_baa3_acde48001122row13_col6{
#             background-color:  #7e03a8;
#             color:  #f1f1f1;
#         }#T_98d31bba_ecb2_11ea_baa3_acde48001122row1_col8{
#             background-color:  #b22b8f;
#             color:  #f1f1f1;
#         }#T_98d31bba_ecb2_11ea_baa3_acde48001122row1_col9{
#             background-color:  #b83289;
#             color:  #f1f1f1;
#         }#T_98d31bba_ecb2_11ea_baa3_acde48001122row1_col10{
#             background-color:  #a01a9c;
#             color:  #f1f1f1;
#         }#T_98d31bba_ecb2_11ea_baa3_acde48001122row1_col11,#T_98d31bba_ecb2_11ea_baa3_acde48001122row4_col10,#T_98d31bba_ecb2_11ea_baa3_acde48001122row8_col11{
#             background-color:  #a62098;
#             color:  #f1f1f1;
#         }#T_98d31bba_ecb2_11ea_baa3_acde48001122row1_col12,#T_98d31bba_ecb2_11ea_baa3_acde48001122row9_col12{
#             background-color:  #b42e8d;
#             color:  #f1f1f1;
#         }#T_98d31bba_ecb2_11ea_baa3_acde48001122row1_col13{
#             background-color:  #44039e;
#             color:  #f1f1f1;
#         }#T_98d31bba_ecb2_11ea_baa3_acde48001122row2_col0{
#             background-color:  #7801a8;
#             color:  #f1f1f1;
#         }#T_98d31bba_ecb2_11ea_baa3_acde48001122row2_col1,#T_98d31bba_ecb2_11ea_baa3_acde48001122row12_col3{
#             background-color:  #6300a7;
#             color:  #f1f1f1;
#         }#T_98d31bba_ecb2_11ea_baa3_acde48001122row2_col3,#T_98d31bba_ecb2_11ea_baa3_acde48001122row2_col6,#T_98d31bba_ecb2_11ea_baa3_acde48001122row7_col6{
#             background-color:  #5e01a6;
#             color:  #f1f1f1;
#         }#T_98d31bba_ecb2_11ea_baa3_acde48001122row2_col4,#T_98d31bba_ecb2_11ea_baa3_acde48001122row8_col5{
#             background-color:  #41049d;
#             color:  #f1f1f1;
#         }#T_98d31bba_ecb2_11ea_baa3_acde48001122row2_col5,#T_98d31bba_ecb2_11ea_baa3_acde48001122row10_col0,#T_98d31bba_ecb2_11ea_baa3_acde48001122row12_col2{
#             background-color:  #5c01a6;
#             color:  #f1f1f1;
#         }#T_98d31bba_ecb2_11ea_baa3_acde48001122row2_col9{
#             background-color:  #8606a6;
#             color:  #f1f1f1;
#         }#T_98d31bba_ecb2_11ea_baa3_acde48001122row2_col10,#T_98d31bba_ecb2_11ea_baa3_acde48001122row9_col11{
#             background-color:  #bd3786;
#             color:  #f1f1f1;
#         }#T_98d31bba_ecb2_11ea_baa3_acde48001122row2_col11{
#             background-color:  #5601a4;
#             color:  #f1f1f1;
#         }#T_98d31bba_ecb2_11ea_baa3_acde48001122row2_col12{
#             background-color:  #5002a2;
#             color:  #f1f1f1;
#         }#T_98d31bba_ecb2_11ea_baa3_acde48001122row2_col13{
#             background-color:  #e26660;
#             color:  #000000;
#         }#T_98d31bba_ecb2_11ea_baa3_acde48001122row3_col0{
#             background-color:  #c8437b;
#             color:  #f1f1f1;
#         }#T_98d31bba_ecb2_11ea_baa3_acde48001122row3_col1,#T_98d31bba_ecb2_11ea_baa3_acde48001122row6_col1,#T_98d31bba_ecb2_11ea_baa3_acde48001122row9_col2{
#             background-color:  #6001a6;
#             color:  #f1f1f1;
#         }#T_98d31bba_ecb2_11ea_baa3_acde48001122row3_col2,#T_98d31bba_ecb2_11ea_baa3_acde48001122row6_col7{
#             background-color:  #9613a1;
#             color:  #f1f1f1;
#         }#T_98d31bba_ecb2_11ea_baa3_acde48001122row3_col4{
#             background-color:  #8405a7;
#             color:  #f1f1f1;
#         }#T_98d31bba_ecb2_11ea_baa3_acde48001122row3_col5{
#             b

# %%
# EJERCICIO - Feature Engineering
# En esta seccion incluya transformaciones, scaling, eliminar o crear variables segun considere apropiado.

data = data.drop('trestbps',axis=1)
data = data.drop('exang',axis=1)

X = np.array((data.loc[:, data.columns != 'target']))
y = np.array(data['target'])

data
# Out:
#      age  sex  cp  chol  fbs  restecg  thalach  oldpeak  slope  ca  thal  \
# 0     63    1   3   233    1        0      150      2.3      0   0     1
# 1     37    1   2   250    0        1      187      3.5      0   0     2
# 2     41    0   1   204    0        0      172      1.4      2   0     2
# 3     56    1   1   236    0        1      178      0.8      2   0     2
# 4     57    0   0   354    0        1      163      0.6      2   0     2
# ..   ...  ...  ..   ...  ...      ...      ...      ...    ...  ..   ...
# 298   57    0   0   241    0        1      123      0.2      1   0     3
# 299   45    1   3   264    0        1      132      1.2      1   0     3
# 300   68    1   0   193    1        1      141      3.4      1   2     3
# 301   57    1   0   131    0        1      115      1.2      1   1     3
# 302   57    0   1   236    0        0      174      0.0      1   1     2
#
#      target
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
# ..      ...
# 298       0
# 299       0
# 300       0
# 301       0
# 302       0
#
# [303 rows x 12 columns]

# %%
# EJERCICIO - Entrenar Modelo & Resampling
# Utilize SKlearn para entrenar el modelo de logistic regression. 
# Como ud solo tiene este dataset, recuerde utilizar la mejor tecnica de resampling. (ver notebook #2)


model = LogisticRegression(multi_class='multinomial', max_iter=1000)
scores = cross_val_score(model, X, y.reshape(-1), cv=10)

print("Exactitud de cada particion:", scores)
print("Exactitud Promedio:", scores.mean())

# Valores antes de transformaciones
#Exactitud de cada particion: [0.87096774 0.80645161 0.83870968 0.86666667 0.9        0.76666667
# 0.86666667 0.83333333 0.7        0.73333333]
#Exactitud Promedio: 0.8182795698924732
# Out:
# Exactitud de cada particion: [0.93548387 0.77419355 0.90322581 0.9        0.9        0.7
#  0.83333333 0.93333333 0.7        0.76666667]
# Exactitud Promedio: 0.8346236559139785

# %%
# EJERCICIO - Metricas y Evaluacion
# Implemente la matrix de confusion y calcule todas las metricas del notebook #4 utilizando classification_report 
# y accuracy_score. Considere el resultado obtenido e itere sobre todo el notebook hasta sentirse satisfecho con
# los resultados. 
# ** ES VALIDO HACER BENCHMARK CON SUS COMPANEROS DE CLASE ** pueden postear sus metricas en el Grupo de WA para
# comparar resultados.

model.fit(X,y)
y_prima = model.predict(X)

accuracy_score(y, y_prima)

print(classification_report(y, y_prima ))


# Valores antes de transformaciones
#         precision recall  f1-score   support
#
#           0       0.89      0.76      0.82       138
#           1       0.82      0.92      0.87       165
#
#    accuracy                           0.85       303
#   macro avg       0.86      0.84      0.84       303
#weighted avg       0.85      0.85      0.85       303
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.80      0.84       138
#            1       0.84      0.91      0.87       165
#
#     accuracy                           0.86       303
#    macro avg       0.86      0.85      0.86       303
# weighted avg       0.86      0.86      0.86       303

# %%
#Deberia dar 1
print("Tiene problemas:" ,model.predict([[63,1,3,233,1,0,150,2.3,0,0,1]]))

#Deberia dar 0
print("Tiene problemas:" ,model.predict([[57,1,0,131,0,1,115,1.2,1,1,3]]))
# Out:
# Tiene problemas: [1]
# Tiene problemas: [0]

# %%
# Bienvenidos al mundo de machine learning!
